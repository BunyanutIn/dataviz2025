# %% [markdown]
# <a href="https://colab.research.google.com/github/BunyanutIn/dataviz2025/blob/main/Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
bfs_outcomes_df = pd.read_csv('/content/2025-01-bedfordshire-outcomes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3715834832.py in <cell line: 0>()
# ----> 1 bfs_outcomes_df = pd.read_csv('/content/2025-01-bedfordshire-outcomes.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
bfs_outcomes_df
# Out:
#                                                Crime ID    Month  \
# 0     52929bd151e1826911839f4b57e493df892c8ff3fc0952...  2025-01
# 1     29e1591b3a59ab11db949797202743d4eb2a8e009648e0...  2025-01
# 2     618de6846fec73e8ce3cdfef1e1f83a56371214e56d2ee...  2025-01
# 3     ac32fb4e82430d595494425c42d9c456f1a07b24964d61...  2025-01
# 4     b861fd8847708c11a0e49b6d01ac11fbb91f26bfac78c8...  2025-01
# ...                                                 ...      ...
# 4338  1e7e0812dc73df2cca19373d4f87e8c65ac11dede664a2...  2025-01
# 4339  9d1bfe642c0b3627655317127dfaa61c345f5db8e55fb9...  2025-01
# 4340  ec3b74e32c46f582e1962ae3bf6b19606e5464fc842c54...  2025-01
# 4341  8c20dfcdb9d4ee983969c151bdf14f282e00fd56875192...  2025-01
# 4342  cfc73c97b8b7f367924025ed0394ac87873e43a258d3e4...  2025-01
#
#               Reported by         Falls within  Longitude   Latitude  \
# 0     Bedfordshire Police  Bedfordshire Police  -0.271341  52.057223
# ...

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_stopandsearch = '/content/drive/MyDrive/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
path_to_stopandsearch
# Out:
# '/content/drive/MyDrive/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %% [markdown]
# ## load data to memory

# %%
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
stopandsearch_df.tail()
# Out:
#                           Type                       Date  \
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 385                         False                 NaN  51.878459  -0.422384
# 386                         False                 NaN  51.878459  -0.422384
#
#      Gender Age range                             Self-defined ethnicity  \
# 382  Female   over 34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
stopandsearch_df['Outcome']
# Out:
# 0                            Arrest
# 1      A no further action disposal
# 2      A no further action disposal
# 3      A no further action disposal
# 4      A no further action disposal
#                    ...
# 382    A no further action disposal
# 383    A no further action disposal
# 384            Community resolution
# 385    A no further action disposal
# 386    A no further action disposal
# Name: Outcome, Length: 387, dtype: object

# %%
stopandsearch_df['Outcome'][200]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df.loc[[200, 384], 'Object of search']
# Out:
# 200            Controlled drugs
# 384    Article for use in theft
# Name: Object of search, dtype: object

# %%
stopandsearch_df[ 'Object of search'][384 : 386]
# Out:
# 384    Article for use in theft
# 385            Controlled drugs
# Name: Object of search, dtype: object

# %% [markdown]
# ## list ซ้อน list ซ้อน Dict ซ้อน list

# %%
ex_list = [[[1,2,3] , ['a' , 'b' , 'c']] ,
                [['x' , 'y' , 'z'] , ['ab' , 1 , 2]],
                [{'a' : 1, 'b' : 2} , {'XX' : 5, 'YY':6}]]

# %%
ex_list[1][1][2]
# Out:
# 2

# %%
#ดึงเลข 5
ex_list[2][1]['XX']
# Out:
# 5

# %% [markdown]
# #### .iloc

# %%
stopandsearch_df.iloc[200 , -3]
# Out:
# 'A no further action disposal'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
stopandsearch_df.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing'],
#       dtype='object')

# %%
smaller_table =stopandsearch_df[['Outcome','Age range','Longitude','Latitude','Self-defined ethnicity']] [:5]
smaller_table
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 1  A no further action disposal     10-17   -0.29660  52.132059
# 2  A no further action disposal     10-17   -0.29660  52.132059
# 3  A no further action disposal     10-17   -0.29660  52.132059
# 4  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
stopandsearch_df.iloc[1:5,:-10]
# Out:
#             Type                       Date  Part of a policing operation  \
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude
# 1                 NaN  52.132059
# 2                 NaN  52.132059
# 3                 NaN  52.132059
# 4                 NaN  52.132059

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query) (conditional statement)

# %% [markdown]
# #### อยากได้ row ที่เป็น Part of a policing operation

# %%
stopandsearch_df['Part of a policing operation']

# %%
#การที่จะสกัด ต้องสร้างลิสที่มีค่าทรู/ฟลอส ที่มีความยาวเท่ากับจำนวนโรลจากตารางที่จะดึง

stopandsearch_df['Part of a policing operation'] == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Name: Part of a policing operation, Length: 387, dtype: bool

# %%
stopandsearch_df[stopandsearch_df['Part of a policing operation'] == True]
# Out:
#                Type                       Date  Part of a policing operation  \
# 8     Person search  2025-01-01T14:35:00+00:00                          True
# 9     Person search  2025-01-01T15:10:00+00:00                          True
# 10    Person search  2025-01-01T15:10:00+00:00                          True
# 21    Person search  2025-01-03T11:22:00+00:00                          True
# 23   Vehicle search  2025-01-03T13:05:00+00:00                          True
# ..              ...                        ...                           ...
# 372   Person search  2025-01-31T13:13:00+00:00                          True
# 373   Person search  2025-01-31T14:00:00+00:00                          True
# 374   Person search  2025-01-31T14:54:00+00:00                          True
# 379   Person search  2025-01-31T19:04:00+00:00                          True
# 380   Person search  2025-01-31T21:00:00+00:00                          True
#
# ...

# %% [markdown]
# ## ตัวอย่าง Table Query แบบง่าย

# %%
smaller_table
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 1  A no further action disposal     10-17   -0.29660  52.132059
# 2  A no further action disposal     10-17   -0.29660  52.132059
# 3  A no further action disposal     10-17   -0.29660  52.132059
# 4  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %%
smaller_table [[True , False , True , False , False]]
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 2  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 2  White - English/Welsh/Scottish/Northern Irish/...

# %%
#ถ้าน้อยกว่า
smaller_table [[True , False , True , False]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-52-1590273992.py in <cell line: 0>()
#       1 #ถ้าน้อยกว่า
# ----> 2 smaller_table [[True , False , True , False]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    4141             )
#    4142         elif len(key) != len(self.index):
# -> 4143             raise ValueError(
#    4144                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    4145             )
#
# ...

# %% [markdown]
# # quiz 8 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (387-25)*[False]

# %%
stopandsearch_df[list_log1+list_logM+list_log2]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# 8                Person search  2025-01-01T14:35:00+00:00
# 9                Person search  2025-01-01T15:10:00+00:00
# 372              Person search  2025-01-31T13:13:00+00:00
# 373              Person search  2025-01-31T14:00:00+00:00
# 374              Person search  2025-01-31T14:54:00+00:00
# 375              Person search  2025-01-31T15:00:00+00:00
# 376              Person search  2025-01-31T16:20:00+00:00
# ...

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are True, the rest are False.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (387-25)*[False]

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# # Quiz 8-2
#
# 1. อยากทราบว่า ในเดือนกุมภาพันธ์ มี 2025 ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White-English,... เมือง city of london หรือ cmabrigeshire มีเยอะกว่ากัน และ เยอะกว่ากันเท่าไหร่

# %%
london_df = pd.read_csv('/content/drive/MyDrive/Data/2025-02/2025-02-city-of-london-stop-and-search.csv')
cambridge_df = pd.read_csv('/content/drive/MyDrive/Data/2025-02/2025-02-cambridgeshire-stop-and-search.csv')

# %%
sum_london = sum(london_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British')
sum_london
# Out:
# 15

# %%
sum_cambridge = sum(cambridge_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British')
sum_cambridge
# Out:
# 69

# %%
print(f' ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง London มีจำนวน {sum_london} คน')
print(f' ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง Cambridge มีจำนวน {sum_cambridge} คน')

diff_sum_city = sum_cambridge - sum_london
if sum_london > sum_cambridge:
  print(f' ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง London มีจำนวนมากกว่าผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง Cambridge จำนวน {diff_sum_city}')

elif sum_cambridge > sum_london:
  print(f' ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง Cambridge มีจำนวนมากกว่าผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง London จำนวน {diff_sum_city} คน')
# Out:
#  ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง London มีจำนวน 15 คน
#  ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง Cambridge มีจำนวน 69 คน
#  ผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง Cambridge มีจำนวนมากกว่าผู้ที่ถูกเรียก-ค้น ที่เป็นคน White ในเมือง London จำนวน 54 คน

# %%
os.listdir('/content/drive/MyDrive/Data/2025-02')
# Out:
# ['2025-02-bedfordshire-street.csv',
#  '2025-02-city-of-london-street.csv',
#  '2025-02-avon-and-somerset-street.csv',
#  '2025-02-cumbria-street.csv',
#  '2025-02-cambridgeshire-street.csv',
#  '2025-02-devon-and-cornwall-street.csv',
#  '2025-02-derbyshire-street.csv',
#  '2025-02-durham-street.csv',
#  '2025-02-cleveland-street.csv',
#  '2025-02-dorset-street.csv',
#  '2025-02-dyfed-powys-street.csv',
#  '2025-02-gloucestershire-street.csv',
#  '2025-02-gwent-street.csv',
#  '2025-02-leicestershire-street.csv',
#  '2025-02-lincolnshire-street.csv',
#  '2025-02-merseyside-street.csv',
#  '2025-02-norfolk-street.csv',
#  '2025-02-north-wales-street.csv',
#  '2025-02-north-yorkshire-street.csv',
#  '2025-02-lancashire-street.csv',
#  '2025-02-suffolk-street.csv',
#  '2025-02-surrey-street.csv',
#  '2025-02-northumbria-street.csv',
#  '2025-02-warwickshire-street.csv',
#  '2025-02-west-mercia-street.csv',
#  '2025-02-wiltshire-street.csv',
#  '2025-02-south-yorkshire-street.csv',
# ...

# %% [markdown]
# # HW 4 (group) ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
import pandas as pd
import glob
import os

# 1. ทำการเชื่อมต่อกับ Google Drive (เหมือนเดิม)
from google.colab import drive
drive.mount('/content/drive')

# 2. กำหนด Path หลักและรูปแบบของไฟล์ที่ต้องการค้นหา
# เราจะใช้เครื่องหมาย * (Wildcard) แทนส่วนของชื่อไฟล์หรือโฟลเดอร์ที่เปลี่ยนแปลงไป
# รูปแบบ: ค้นหาไฟล์ .csv ที่อยู่ในโฟลเดอร์ 2025-XX ใดๆ ก็ตาม
path_pattern = '/content/drive/MyDrive/Data/2025-*/*-stop-and-search.csv'
all_stopandsearch = glob.glob(path_pattern)

print(f"ค้นพบไฟล์ CSV ทั้งหมด: {len(all_stopandsearch)} ไฟล์")
# ลองแสดงตัวอย่าง 5 ไฟล์แรกที่เจอ
print("ตัวอย่างไฟล์ที่พบ:")
for f in all_stopandsearch[:5]:
    print(f)
print("-" * 50)

# 4. สร้าง Loop เพื่ออ่านไฟล์ทั้งหมดและรวมเป็น DataFrame เดียว
all_dfs = [] # สร้าง list ว่างเพื่อเก็บ DataFrame ชั่วคราว

for filepath in all_stopandsearch:
    # อ่านไฟล์ CSV จาก path ที่ได้มา
    df = pd.read_csv(filepath)

    # --- ส่วนสำคัญ: ดึงชื่อเขตตำรวจจากชื่อไฟล์ ---
    # ชื่อไฟล์: '.../2025-01-avon-and-somerset-stop-and-search.csv'
    # 1. ดึงเฉพาะชื่อไฟล์ออกมา: os.path.basename(filepath) -> '2025-01-avon-and-somerset-stop-and-search.csv'
    filename = os.path.basename(filepath)
    # 2. แยกส่วนประกอบของชื่อไฟล์ด้วยเครื่องหมาย '-'
    parts = filename.split('-')
    # 3. ชื่อเขตตำรวจจะอยู่ระหว่างส่วนของวันที่ (2 ส่วนแรก) และ 3 ส่วนท้าย ('stop', 'and', 'search.csv')
    force_name_parts = parts[2:-3]
    # 4. นำชิ้นส่วนชื่อมารวมกันและจัดรูปแบบตัวพิมพ์ให้สวยงาม (เช่น 'avon and somerset' -> 'Avon And Somerset')
    force_name = ' '.join(force_name_parts).title()

    # เพิ่มคอลัมน์ 'Police Force' เข้าไปใน DataFrame
    df['Police Force'] = force_name

    all_dfs.append(df)

# รวม DataFrame ทั้งหมดใน list ให้เป็น DataFrame เดียว
combined_df = pd.concat(all_dfs, ignore_index=True)

print("รวมข้อมูลจากทุกไฟล์สำเร็จแล้ว!")
print(f"DataFrame ใหม่มีข้อมูลทั้งหมด: {len(combined_df):,} แถว")
print(f"จากเขตตำรวจทั้งหมด: {combined_df['Police Force'].nunique()} เขต")
print("-" * 50)

# --- จากตรงนี้ สามารถนำโค้ดวิเคราะห์จากคำตอบที่แล้วมาใช้ต่อได้เลย ---

# คัดกรองข้อมูลเฉพาะผู้ถูกเรียกค้นที่เป็นคน Asia
asian_stops_df = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# จัดกลุ่มและนับจำนวนตามเขตตำรวจ
asian_counts = asian_stops_df['Police Force'].value_counts()

print("สรุปผลการเรียกค้นบุคคลเชื้อสายเอเชียในรอบ 5 เดือน (จากข้อมูลที่โหลดแบบอัตโนมัติ):\n")
print(f"📈 เขตที่มีการเรียกค้นมากที่สุด: {asian_counts.idxmax()} ({asian_counts.max():,} ครั้ง)")
print(f"📉 เขตที่มีการเรียกค้นน้อยที่สุด: {asian_counts.idxmin()} ({asian_counts.min():,} ครั้ง)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ค้นพบไฟล์ CSV ทั้งหมด: 186 ไฟล์
# ตัวอย่างไฟล์ที่พบ:
# /content/drive/MyDrive/Data/2025-04/2025-04-avon-and-somerset-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-btp-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-cambridgeshire-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-cheshire-stop-and-search.csv
# --------------------------------------------------
# รวมข้อมูลจากทุกไฟล์สำเร็จแล้ว!
# DataFrame ใหม่มีข้อมูลทั้งหมด: 155,291 แถว
# จากเขตตำรวจทั้งหมด: 38 เขต
# --------------------------------------------------
# สรุปผลการเรียกค้นบุคคลเชื้อสายเอเชียในรอบ 5 เดือน (จากข้อมูลที่โหลดแบบอัตโนมัติ):
#
# 📈 เขตที่มีการเรียกค้นมากที่สุด: West Midlands (2,104 ครั้ง)
# 📉 เขตที่มีการเรียกค้นน้อยที่สุด: Durham (5 ครั้ง)

# %% [markdown]
# # HW 5(เดี่ยว) แก้จาก code เดิม ยอดรวมทุกเมือง เดือนไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
import pandas as pd
import glob
import os

# 1. เชื่อมต่อ Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. ระบุ pattern ของไฟล์ (แยกตามเดือนในโฟลเดอร์ 2025-XX)
path_pattern = '/content/drive/MyDrive/Data/2025-*/*-stop-and-search.csv'
all_stopandsearch = glob.glob(path_pattern)

print(f"ค้นพบไฟล์ CSV ทั้งหมด: {len(all_stopandsearch)} ไฟล์")
print("ตัวอย่างไฟล์ที่พบ:")
for f in all_stopandsearch[:5]:
    print(f)
print("-" * 50)

# 3. รวมข้อมูลทุกไฟล์
all_dfs = []

for filepath in all_stopandsearch:
    df = pd.read_csv(filepath)

    # --- ดึงเดือนจากชื่อโฟลเดอร์ ---
    # โครงสร้างโฟลเดอร์: .../2025-01/...
    month_folder = os.path.basename(os.path.dirname(filepath))  # ได้เป็น '2025-01'
    df['Month'] = month_folder  # เพิ่มคอลัมน์เดือน

    all_dfs.append(df)

combined_df = pd.concat(all_dfs, ignore_index=True)

print("รวมข้อมูลจากทุกไฟล์สำเร็จแล้ว!")
print(f"DataFrame ใหม่มีข้อมูลทั้งหมด: {len(combined_df):,} แถว")
print(f"จาก {combined_df['Month'].nunique()} เดือน")
print("-" * 50)

# 4. กรองเฉพาะผู้ถูกเรียกค้นที่เป็นคน Asia
asian_stops_df = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# 5. รวมยอดตามเดือน
asian_counts = asian_stops_df['Month'].value_counts().sort_index()

print("สรุปจำนวนการเรียกค้นบุคคลเชื้อสายเอเชียรวมทุกเมือง (แยกตามเดือน):")
print(f"📈 เดือนไหนมีจำนวนมากที่สุด: {asian_counts.idxmax()} ({asian_counts.max():,} ครั้ง)")
print(f"📉 เดือนไหนมีจำนวนน้อยที่สุด: {asian_counts.idxmin()} ({asian_counts.min():,} ครั้ง)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ค้นพบไฟล์ CSV ทั้งหมด: 186 ไฟล์
# ตัวอย่างไฟล์ที่พบ:
# /content/drive/MyDrive/Data/2025-04/2025-04-avon-and-somerset-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-btp-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-cambridgeshire-stop-and-search.csv
# /content/drive/MyDrive/Data/2025-04/2025-04-cheshire-stop-and-search.csv
# --------------------------------------------------
# รวมข้อมูลจากทุกไฟล์สำเร็จแล้ว!
# DataFrame ใหม่มีข้อมูลทั้งหมด: 155,291 แถว
# จาก 5 เดือน
# --------------------------------------------------
# สรุปจำนวนการเรียกค้นบุคคลเชื้อสายเอเชียรวมทุกเมือง (แยกตามเดือน):
# 📈 เดือนไหนมีจำนวนมากที่สุด: 2025-01 (2,874 ครั้ง)
# 📉 เดือนไหนมีจำนวนน้อยที่สุด: 2025-05 (1,737 ครั้ง)

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %% [markdown]
# # ตรวจสอบ Missing

# %%
# .isnull() ตรวจสอบค่าความจริงว่ามีหรือไม่มี ค่า Missing
stopandsearch_df.isnull()
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0    False  False                         False                True     False
# 1    False  False                         False                True     False
# 2    False  False                         False                True     False
# 3    False  False                         False                True     False
# 4    False  False                         False                True     False
# ..     ...    ...                           ...                 ...       ...
# 382  False  False                         False                True     False
# 383  False  False                         False                True     False
# 384  False  False                         False                True     False
# 385  False  False                         False                True     False
# 386  False  False                         False                True     False
#
# ...

# %%
#any() คือเราค่าความจริงมา "หรือ or"กัน
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number) , Null

# %%
stopandsearch_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'])
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ## Drop แบบเลือกพิจารณาเฉพาะบาง column

# %%
stopandsearch_df[[['Outcome','Type','Age range']].dropna]

# %%
stopandsearch_df.shape #(12423, 3)
# Out:
# (387, 15)

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'])(inplace=True)

# %%
print(this_data.shape)
print(this_data.dropna().shape)
# Out:
# (226, 11)
# (0, 11)

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = folk_df.copy()

# %%
this_data
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = this_data.dropna(inplace=True)

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) # สมมติ เราต้องใช้ ค่าใน column 'name','description','type'

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %% [markdown]
# # เติม Dummy

# %%
stopandsearch_df.fillna('Unknow')
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation Policing operation   Latitude Longitude  \
# 0                           False             Unknow  51.881481  -0.41311
# 1                           False             Unknow  52.132059   -0.2966
# ...

# %%
stopandsearch_df.fillna('Unknow')

# %%
stopandsearch_df.dropna(subset=['Gender' : 'Unknow']), input

# %%
stopandsearch_df.dropna(['Gender' : 'Unknow']).isnaull().any()
# Out:
#   File "/tmp/ipython-input-3402675469.py", line 1
#     stopandsearch_df.dropna(['Gender' : 'Unknow']).isnaull().any()
#                                       ^
# SyntaxError: invalid syntax

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
['type'].mode()
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
stopandsearch_df['type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
stopandsearch_df['type'].isnull().any()    # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
stopandsearch_df['type'].isnull().all()    # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
stopandsearch_df['spatial'].isnull().any()
# Out:
# True

# %%
stopandsearch_df[stopandsearch_df['spatial'].isnull()]['title']

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
stopandsearch_df.duplicated()
#True คือมีค่าซ้ำ
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Length: 387, dtype: bool

# %% [markdown]
# ## เรียกดูแถวที่ซ้ำ

# %%
stopandsearch_df[stopandsearch_df.duplicated()]
# Out:
#                Type                       Date  Part of a policing operation  \
# 2     Person search  2025-01-01T02:30:00+00:00                         False
# 4     Person search  2025-01-01T02:30:00+00:00                         False
# 43    Person search  2025-01-05T03:25:00+00:00                         False
# 86    Person search  2025-01-08T02:06:00+00:00                         False
# 87    Person search  2025-01-08T02:06:00+00:00                         False
# 88    Person search  2025-01-08T02:06:00+00:00                         False
# 231   Person search  2025-01-19T18:45:00+00:00                         False
# 243   Person search  2025-01-20T15:55:00+00:00                         False
# 244   Person search  2025-01-20T15:55:00+00:00                         False
# 245   Person search  2025-01-20T15:55:00+00:00                         False
# 289  Vehicle search  2025-01-26T08:49:00+00:00                         False
# ...

# %% [markdown]
# ## เรียกกดูแถวที่ไม่ซ้ำ

# %%
stopandsearch_df.duplicated()==False
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 387, dtype: bool

# %%
~stopandsearch_df.duplicated()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 387, dtype: bool

# %% [markdown]
# ## ลบ Duplicated

# %%
stopandsearch_df[~stopandsearch_df.duplicated()]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df[~stopandsearch_df.duplicated()==False]
# Out:
#                Type                       Date  Part of a policing operation  \
# 2     Person search  2025-01-01T02:30:00+00:00                         False
# 4     Person search  2025-01-01T02:30:00+00:00                         False
# 43    Person search  2025-01-05T03:25:00+00:00                         False
# 86    Person search  2025-01-08T02:06:00+00:00                         False
# 87    Person search  2025-01-08T02:06:00+00:00                         False
# 88    Person search  2025-01-08T02:06:00+00:00                         False
# 231   Person search  2025-01-19T18:45:00+00:00                         False
# 243   Person search  2025-01-20T15:55:00+00:00                         False
# 244   Person search  2025-01-20T15:55:00+00:00                         False
# 245   Person search  2025-01-20T15:55:00+00:00                         False
# 289  Vehicle search  2025-01-26T08:49:00+00:00                         False
# ...

# %%
stopandsearch_df['Latitude'].mean()
# Out:
# np.float64(51.95827930529595)

# %%
stopandsearch_df.fillna({'Latitude' : stopandsearch_df['Latitude'].mean(),              #แทนค่า Lat ด้วยค่าเฉลี่ย
                                 'Longitude' : stopandsearch_df['Longitude'].mean(),            #แทนค่า Long ด้วยค่าเฉลี่ย
                                'Age range' :  stopandsearch_df['Age range'].mode()},           #แทนค่า Age ด้วยค่าฐานนิยม
                                    inplace=True)

# %% [markdown]
# # Quiz9 หาดูว่า Row ไหนบ้างที่ยังมี Missing ใน column Age range อยู่

# %%
stopandsearch_df['Age range'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Name: Age range, Length: 387, dtype: bool

# %%
stopandsearch_df[stopandsearch_df['Age range'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
stopandsearch_df[stopandsearch_df['Age range'].iloc()]

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
this_data = stopandsearch_df.iloc[:10,:]

# %%
this_data
# Out:
#              Type                       Date  Part of a policing operation  \
# 0   Person search  2025-01-01T00:35:00+00:00                         False
# 1   Person search  2025-01-01T02:30:00+00:00                         False
# 2   Person search  2025-01-01T02:30:00+00:00                         False
# 3   Person search  2025-01-01T02:30:00+00:00                         False
# 4   Person search  2025-01-01T02:30:00+00:00                         False
# 5   Person search  2025-01-01T10:00:00+00:00                         False
# 6  Vehicle search  2025-01-01T10:00:00+00:00                         False
# 7   Person search  2025-01-01T12:12:00+00:00                         False
# 8   Person search  2025-01-01T14:35:00+00:00                          True
# 9   Person search  2025-01-01T15:10:00+00:00                          True
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481  -0.413110    Male     25-34
# ...

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, Type                                                                            Person search
# Date                                                                2025-01-01T00:35:00+00:00
# Part of a policing operation                                                            False
# Policing operation                                                                        NaN
# Latitude                                                                            51.881481
# Longitude                                                                            -0.41311
# Gender                                                                                   Male
# Age range                                                                               25-34
# Self-defined ethnicity                      Mixed/Multiple ethnic groups - Any other Mixed...
# Officer-defined ethnicity                                                               Other
# ...

# %%
each_row
# Out:
# (9,
#  Type                                                                Person search
#  Date                                                    2025-01-01T15:10:00+00:00
#  Part of a policing operation                                                 True
#  Policing operation                                                            NaN
#  Latitude                                                                51.958279
#  Longitude                                                               -0.414856
#  Gender                                                                       Male
#  Age range                                                                 over 34
#  Self-defined ethnicity                         White - Any other White background
#  Officer-defined ethnicity                                                   White
#  Legislation                                 Misuse of Drugs Act 1971 (section 23)
# ...

# %%
each_row[1]
# Out:
# Type                                                                Person search
# Date                                                    2025-01-01T15:10:00+00:00
# Part of a policing operation                                                 True
# Policing operation                                                            NaN
# Latitude                                                                51.958279
# Longitude                                                               -0.414856
# Gender                                                                       Male
# Age range                                                                 over 34
# Self-defined ethnicity                         White - Any other White background
# Officer-defined ethnicity                                                   White
# Legislation                                 Misuse of Drugs Act 1971 (section 23)
# ...

# %%
each_row[1]['Date']
# Out:
# '2025-01-01T15:10:00+00:00'

# %%
for each_row in this_data.iterrows():
    print(each_row[1]['Date'],
          each_row[1]['Self-defined ethnicity'],
          each_row[1]['Legislation'],
          sep='//'
          ='\n*************************\n')

# %% [markdown]
# * สร้างตารางใหม่
# * ต่อตารางแกน X แกน Y
# * groupby
# * save ตาราง

# %% [markdown]
# # สร้างตารางใหม่
#
#
# ![image.png](data:image/png;base64,...)

# %%
police = [
         {'วันที่' : '01-09-2568','ชื่อ' : 'รุ่งแสง', 'รหัส' : '292' , 'ความผิด' : 'ไม่ใส่หมวกกันน็อก' },
         {'วันที่' : '02-09-2568','ชื่อ' : 'พรพรรณ', 'รหัส' : '377' , 'ความผิด' : 'ฝ่าไฟจราจร'},
         {'วันที่' : '03-09-2568','ชื่อ' : 'รุ่งแสง', 'รหัส' : '385' , 'ความผิด' : 'ขโมยจักรยานยนต์'}]

# %%
kku_police = pd.DataFrame(police)

# %%
kku_police
# Out:
#        วันที่     ชื่อ รหัส            ความผิด
# 0  01-09-2568  รุ่งแสง  292  ไม่ใส่หมวกกันน็อก
# 1  02-09-2568   พรพรรณ  377         ฝ่าไฟจราจร
# 2  03-09-2568  รุ่งแสง  385    ขโมยจักรยานยนต์

# %% [markdown]
# # Save ตาราง

# %%
kku_police.to_csv('kku_police.csv')

# %%
kku_police.to_excel('kku_police.xlsx',sheet_name='ความผิด')

# %% [markdown]
# # ต่อตาราง

# %% [markdown]
# # แกน X (เพิ่ม column -> เพิ่มรายละเอียดให้ข้อมูล)

# %%
outcomes = pd.read_csv('/content/drive/MyDrive/Data/2025-01/2025-01-avon-and-somerset-outcomes.csv')

# %%
street = pd.read_csv('/content/drive/MyDrive/Data/2025-01/2025-01-avon-and-somerset-street.csv')

# %%
outcomes.head(2)

# %%
street.head(2)

# %% [markdown]
# ### ต่อแบบเลือกมาเฉพาะบาง column (```map()```)

# %%
street['Crime ID'].map(outcomes.set_index('Crime ID')['Outcome type'])

# %% [markdown]
# ### จะเกิด error เมื่อ ตารางที่เราจะไปเอา data มามี id ที่ duplicate เพราะไม่รู้จะเอาค่าไหนมา

# %% [markdown]
# ### เราจะแก้ Duplicate

# %%
outcomes[outcomes.duplicated()].head()

# %%
outcomes_dedup = outcomes.drop_duplicates(keep='last',subset=['Crime ID'])
outcomes_dedup.head()

# %% [markdown]
# ได้ column ที่ map เสร็จแล้ว

# %%
street['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])

# %% [markdown]
# ## เพิ่ม column ใหม่ในตาราง

# %%
street['Outcome type'] = street['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
street.head()

# %%
street[street['Outcome type'].notnull()]

# %% [markdown]
# ## แกน Y (เพิ่ม row -> เพิ่มจำนวนข้อมูล)

# %%
outcomes.shape

# %%
outcomes.head()

# %%
Loutcomes1 = pd.read_csv('/content/drive/MyDrive/Data/2025-01/2025-01-city-of-london-outcomes.csv')
Loutcomes2 = pd.read_csv('/content/drive/MyDrive/Data/2025-02/2025-02-city-of-london-outcomes.csv')
Loutcomes3 = pd.read_csv('/content/drive/MyDrive/2025-03/2025-03-city-of-london-outcomes.csv')

# %% [markdown]
# ### ต่อตารางแกน Y (```map()```)

# %%
Loutcome_123 = pd.concat([Loutcomes1,Loutcomes2,Loutcomes3])

# %%
print(f'month1 : {Loutcomes1.shape[0]}, month2 : {Loutcomes2.shape[0]}, month3 : {Loutcomes3.shape[0]}')
print(f'total : {Loutcome_123.shape[0]}')

# %% [markdown]
# [link text](https://)# groupby
#
# ![GROUPBY.png](data:image/png;base64,...)

# %%
stopNsearch = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-city-of-london-stop-and-search.csv')
stopNsearch.head()

# %% [markdown]
# เดือน มกราคม มี case ที่ถูกเรียกค้น โดยผู้ต้องสงสัยเป็นเชื้อชาติต่างๆอย่างละกี่ case

# %%
stopNsearch.groupby('Self-defined ethnicity').count()

# %%
stopNsearch.groupby('Self-defined ethnicity').count().reset_index()

# %%
stopNsearch.groupby(['Self-defined ethnicity','Officer-defined ethnicity']).count()

# %%
stopNsearch.groupby(['Officer-defined ethnicity','Self-defined ethnicity']).count()
